# %% [markdown]
# <a href="https://colab.research.google.com/github/bnq2k777/NM/blob/main/lekcia1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 1.1
a
# Out:
# 1.1

# %%
b = 2.3
print(a)
b
# Out:
# 1.1
# 2.3
